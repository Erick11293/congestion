# %%
import numpy as np

# %%
bar_s = 0.8
theta_x = 0.1

# %%
p_1_dom = np.linspace(0, 1, 100)

# %%
#  Close solution
a_1 = (theta_x /2)
b_1 = -(theta_x/2 + 1)
c_1 = 1 - bar_s

# %%
p_1 = (- b_1 - np.sqrt(b_1 ** 2 - 4 * a_1 * c_1))/( 2 * a_1)

# %%
#  Close solution
a_0 = ((1 - theta_x) /2)
b_0 = -((1 - theta_x) / 2 + 1  - p_1 * theta_x)
c_0 = 1 - p_1 * theta_x - bar_s

# %%
p_0 = (- b_0 - np.sqrt(b_0 ** 2 - 4 * a_0 * c_0))/( 2 * a_0)

# %%
c = 0.1

# %%
# benefits given p_0 and p_1
pi = ( (theta_x ** 2) * (p_1 ** 2 * (1 - 2 * c) + 2 * p_1 * (1 - p_1) * (1 - c) + (1 - p_1)**2 * 0)
      + 2 * (theta_x) * (1 - theta_x) * (p_0 * p_1 * (1 - 2 * c) + p_1 * (1 - p_0) * (1 - c) + p_0 * (1 - p_1) * (- c) )
      + (theta_x ** 2) * (p_1 ** 2 * (1 - 2 * c) + 2 * p_1 * (1 - p_1) * (1 - c) * (1 - p_1)**2 * 0)

# %%
plt.plot(p_1_dom,(1 - p_1_dom) * (1 - theta_x * p_1_dom/2))
plt.axhline(bar_s)
plt.axvline(p_1)
